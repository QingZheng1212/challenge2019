# %% [markdown]
# # 42184 Data Science for Mobility
# # 42577 Introduction to Business Analytics
# # Challenge 2019

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 

# load the excek file into a pandas dataframe
df = pd.read_excel('/Users/zq/desktop/BA/HouseholdsData.xlsx')

# %%
# show the first five rows of the data
df.head()
# Out:
#     Hogar  EXCLUIR  paraValidacion  Sector    DirCoordX    DirCoordY  \
# 0  100010        0               0       7  335180.8019  6266420.975
# 1  100020        0               0       7  338410.2114  6265607.141
# 2  100030        0               0       7  327863.8248  6257800.086
# 3  100041        0               0       7  327864.0000  6257800.000
# 4  100052        0               0       7  338480.8152  6267296.941
#
#    MontoArr  IngresoHogar      Factor  AnosEstudio  ...  \
# 0    100000        450845  136.393738           11  ...
# 1    120000       1019369   73.843597           11  ...
# 2     70000         80000  180.722809           10  ...
# 3     80000        559259  150.379059           14  ...
# 4    117771        710309  122.001518           12  ...
#
#    Acc_Habitacion_tpte_pub  Acc_Industria_tpte_pub  Acc_Servicios_tpte_pub  \
# 0               6110.62492               671.08681               719.84272
# ...

# %%
#show the variables of the dataset
df.head().T
# Out:
#                                      0             1             2  \
# Hogar                     1.000100e+05  1.000200e+05  1.000300e+05
# EXCLUIR                   0.000000e+00  0.000000e+00  0.000000e+00
# paraValidacion            0.000000e+00  0.000000e+00  0.000000e+00
# Sector                    7.000000e+00  7.000000e+00  7.000000e+00
# DirCoordX                 3.351808e+05  3.384102e+05  3.278638e+05
# DirCoordY                 6.266421e+06  6.265607e+06  6.257800e+06
# MontoArr                  1.000000e+05  1.200000e+05  7.000000e+04
# IngresoHogar              4.508450e+05  1.019369e+06  8.000000e+04
# Factor                    1.363937e+02  7.384360e+01  1.807228e+02
# AnosEstudio               1.100000e+01  1.100000e+01  1.000000e+01
# CLASE                     1.000000e+00  1.000000e+00  1.000000e+00
# Sup_Prom_Constr_Hab_EOD   5.380000e+01  5.960000e+01  5.950000e+01
# Calid_EOD_norm_inv        9.800000e-01  9.800000e-01  9.800000e-01
# ...

# %%
# show the length of the data
len(df)
# Out:
# 18264

# %%
# show summary statistics of each column
df.describe()
# Out:
#                Hogar       EXCLUIR  paraValidacion        Sector  \
# count   18264.000000  18264.000000    18264.000000  18264.000000
# mean   193030.230672      0.121386        0.097624      3.821288
# std     56198.257546      0.326585        0.296813      1.947325
# min    100010.000000      0.000000        0.000000      1.000000
# 25%    145647.750000      0.000000        0.000000      2.000000
# 50%    192085.500000      0.000000        0.000000      4.000000
# 75%    237732.750000      0.000000        0.000000      6.000000
# max    743823.000000      1.000000        1.000000      7.000000
#
#            DirCoordX     DirCoordY      MontoArr  IngresoHogar        Factor  \
# count   18264.000000  1.826400e+04  1.826400e+04  1.826400e+04  18264.000000
# mean   344588.546182  6.292533e+06  1.915436e+05  6.882743e+05    112.314389
# std     10168.072922  1.075723e+04  1.642392e+05  7.287777e+05     74.540944
# ...

# %%
# check the column types
df.dtypes
# Out:
# Hogar                         int64
# EXCLUIR                       int64
# paraValidacion                int64
# Sector                        int64
# DirCoordX                   float64
# DirCoordY                   float64
# MontoArr                      int64
# IngresoHogar                  int64
# Factor                      float64
# AnosEstudio                   int64
# CLASE                         int64
# Sup_Prom_Constr_Hab_EOD     float64
# Calid_EOD_norm_inv          float64
# DensConstr_EOD              float64
# Dist_est_Metro_MC_KM        float64
# Dist_salida_Autop_MC_KM     float64
# Tiempo_Com_Stgo               int64
# Ingreso_Promedio_Zona_MM    float64
# Acc_Comercio_tpte_pub       float64
# Acc_Educacion_tpte_pub      float64
# Acc_Habitacion_tpte_pub     float64
# Acc_Industria_tpte_pub      float64
# Acc_Servicios_tpte_pub      float64
# Acc_Comercio_auto           float64
# Acc_Educacion_auto          float64
# Acc_Habitacion_auto         float64
# ...

# %%
# check the data type in each column
for column in df.columns:
    print("Data type in {} is {}.".format(column,type(df[column][0])))
# Out:
# Data type in Hogar is <class 'numpy.int64'>.
# Data type in EXCLUIR is <class 'numpy.int64'>.
# Data type in paraValidacion is <class 'numpy.int64'>.
# Data type in Sector is <class 'numpy.int64'>.
# Data type in DirCoordX is <class 'numpy.float64'>.
# Data type in DirCoordY is <class 'numpy.float64'>.
# Data type in MontoArr is <class 'numpy.int64'>.
# Data type in IngresoHogar is <class 'numpy.int64'>.
# Data type in Factor is <class 'numpy.float64'>.
# Data type in AnosEstudio is <class 'numpy.int64'>.
# Data type in CLASE is <class 'numpy.int64'>.
# Data type in Sup_Prom_Constr_Hab_EOD is <class 'numpy.float64'>.
# Data type in Calid_EOD_norm_inv is <class 'numpy.float64'>.
# Data type in DensConstr_EOD is <class 'numpy.float64'>.
# Data type in Dist_est_Metro_MC_KM is <class 'numpy.float64'>.
# Data type in Dist_salida_Autop_MC_KM is <class 'numpy.float64'>.
# Data type in Tiempo_Com_Stgo is <class 'numpy.int64'>.
# ...

# %%
# check for empty strings in each column
for column in df.columns:
    print("" in df[column])
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %%
# check for NaNs
for column in df.columns:
    print("column {} has {} null value".format(column, df[column].isnull().sum()))
# Out:
# column Hogar has 0 null value
# column EXCLUIR has 0 null value
# column paraValidacion has 0 null value
# column Sector has 0 null value
# column DirCoordX has 0 null value
# column DirCoordY has 0 null value
# column MontoArr has 0 null value
# column IngresoHogar has 0 null value
# column Factor has 0 null value
# column AnosEstudio has 0 null value
# column CLASE has 0 null value
# column Sup_Prom_Constr_Hab_EOD has 0 null value
# column Calid_EOD_norm_inv has 0 null value
# column DensConstr_EOD has 0 null value
# column Dist_est_Metro_MC_KM has 0 null value
# column Dist_salida_Autop_MC_KM has 0 null value
# column Tiempo_Com_Stgo has 0 null value
# column Ingreso_Promedio_Zona_MM has 0 null value
# column Acc_Comercio_tpte_pub has 0 null value
# column Acc_Educacion_tpte_pub has 0 null value
# column Acc_Habitacion_tpte_pub has 0 null value
# column Acc_Industria_tpte_pub has 0 null value
# column Acc_Servicios_tpte_pub has 0 null value
# ...

# %% [markdown]
# From the result, we can tell that there is no missing values in the dataset.
